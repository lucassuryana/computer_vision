# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## tf.Tensor vs np.array

# %% [markdown]
# Tensors are a type of array used by Tensorflow. They have a lot in common with numpy arrays.

# %%
arr = np.array([[1, 2, 5], [5,7,3]])

# %%
arr
# Out:
# array([[1, 2, 5],
#        [5, 7, 3]])

# %% [markdown]
# Convert a numpy array to a Tensorflow tensor with the following line:

# %%
tensor = tf.convert_to_tensor(arr)

# %% [markdown]
# Access the numpy array by using `.numpy()`

# %%
tensor.numpy()
# Out:
# array([[1, 2, 5],
#        [5, 7, 3]])

# %% [markdown]
# Tensors and array share some attributes, such as shape.

# %%
arr.shape
# Out:
# (2, 3)

# %%
tensor.shape
# Out:
# TensorShape([2, 3])

# %% [markdown]
# ## Operations on tensors

# %% [markdown]
# Similarly to np.arrays, we can perform operation on tensors.

# %%
tensor
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int64, numpy=
# array([[1, 2, 5],
#        [5, 7, 3]])>

# %% [markdown]
# Element-wise multiplication

# %%
tensor*2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int64, numpy=
# array([[ 2,  4, 10],
#        [10, 14,  6]])>

# %% [markdown]
# Broadcasting rules apply.

# %%
tensor*tf.constant([3, 2, 2], dtype=tf.int64)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int64, numpy=
# array([[ 3,  4, 10],
#        [15, 14,  6]])>

# %% [markdown]
# ## Additional attribute & methods

# %% [markdown]
# Find the tensor location

# %%
tensor.device
# Out:
# '/job:localhost/replica:0/task:0/device:CPU:0'

# %% [markdown]
# Move tensor to the gpu by calling `tensor.gpu()`

# %%
tensor.gpu()
# Out:
# WARNING:tensorflow:From /var/folders/f_/yyffkr911d5df0f0yms_7wkxsbvsst/T/ipykernel_39525/2988661624.py:1: _EagerTensorBase.gpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tensor.gpu()
#
# File ~/computer_vision/myenv/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:383, in deprecated.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     375         _PRINTED_WARNING[cls] = True
#     376     _log_deprecation(
#     377         'From %s: %s (from %s) is deprecated and will be removed %s.\n'
#     378         'Instructions for updating:\n%s', _call_location(),
#    (...)
#     381         'in a future version' if date is None else ('after %s' % date),
#     382         instructions)
# --> 383 return func(*args, **kwargs)
#
# File ~/computer_vision/myenv/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:547, in _EagerTensorBase.gpu(self, gpu_index)
#     535 @deprecation.deprecated(None, "Use tf.identity instead.")
#     536 def gpu(self: EagerTensorType, gpu_index=0) -> EagerTensorType:
#     537   """A copy of this Tensor with contents backed by memory on the GPU.
#     538
#     539   Args:
#    (...)
#     545     as this Tensor.
#     546   """
# --> 547   return self._copy(context.context(), "GPU:" + str(gpu_index))
#
# File ~/computer_vision/myenv/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:493, in _EagerTensorBase._copy(self, ctx, device_name)
#     489 def _copy(
#     490     self: EagerTensorType, ctx=None, device_name=None,
#     491 ) -> EagerTensorType:
#     492   """Copies tensor to dest device."""
# --> 493   new_tensor = self._copy_nograd(ctx, device_name)
#     494   # Record the copy on tape and define backprop copy as well.
#     495   if context.executing_eagerly():
#
# File ~/computer_vision/myenv/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:484, in _EagerTensorBase._copy_nograd(self, ctx, device_name)
#     482 try:
#     483   ctx.ensure_initialized()
# --> 484   new_tensor = self._copy_to_device(device_name)
#     485 except core._NotOkStatusException as e:
#     486   raise core._status_to_exception(e) from None
#
# RuntimeError: GPU:0 unknown device.
