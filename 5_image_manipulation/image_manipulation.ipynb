# %%
# Perform masking
from masking import create_mask
from masking import mask_and_display

path = 'data/images/segment-1231623110026745648_480_000_500_000_with_camera_labels_38.png'
color_threshold = [128, 128, 128]
img, mask = create_mask(path, color_threshold)
mask_and_display(img, mask)

# %%
# Calculate barplot for each color RGB
from utils import check_results
import glob
from statistics import calculate_mean_std
from statistics import channel_histogram

image_list = glob.glob('data/images/*')
mean, std = calculate_mean_std(image_list)
check_results(mean, std)
channel_histogram(image_list[:2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 image_list = glob.glob('data/images/*')
#       8 mean, std = calculate_mean_std(image_list)
# ----> 9 check_results(mean, std)
#      10 channel_histogram(image_list[:2])
#
# NameError: name 'check_results' is not defined
